# %%
#This line of code simply demonstrates using logical operators to determine whether access should be granted for correctlogin details
username_correct = input("username: ")
password_correct = input("password: ")

username_correct =True
password_correct = True
account_locked = False

print("Access Granted" if(username_correct and password_correct and not account_locked) else "Access Denied")
# Out:
# username:  promisesteve
# password:  spe3on57
# Access Granted

# %%
#This second line of code is for confirming university scholarship eligibility
score = 85
participated = True
low_income = False

print("Congratulations! Scholarship Approved." if(score >= 80 and participated and not low_income) else "Scholarship Not Approved")
# Out:
# Congratulations! Scholarship Approved.

# %%
#This line of code is to determine whether an emergency alert should be raised
cpu_usage = 75
memory_usage = 92
disk_usage = 60

print("Critical Alert!" if(cpu_usage > 90 or memory_usage > 90 or disk_usage > 95) else "System Healthy")
# Out:
# Critical Alert!

# %%
#Study Buddy Bonus
## These lines of code show a customer is eligible to make a purchase
logged_in = True
in_stock = True
sufficient_wallet_balance = True
account_suspended = False

print("Order confirmed" if(logged_in and in_stock and sufficient_wallet_balance and not account_suspended) else "Order Failed")
# Out:
# Order confirmed
