# %%
#Exercise_1: Creating_Variables
name = "Promise Steve"
age = 26
country = "Nigeria"

print(name)
print(age)
print(country)
# Out:
# Promise Steve
# 26
# Nigeria

# %%
#Salary Calculation_Exercise 2
basic_salary = 180000
bonus = 30000
total_salary = basic_salary + bonus
print(total_salary)
# Out:
# 210000

# %%
#Exercise 3_User_Input
name = input("Enter your name: ")
programme = input("What is your favourite programming language; ")
print(name)
print(programme)
# Out:
# Enter your name:  Promise Steve
# What is your favourite programming language;  Python Programming
# Promise Steve
# Python Programming

# %%
#Exercise 4_Working with data types
name = ("Promise Steve")
age = 25
height = 5.7
igbo_nativity = True

print(type(name))
print(type(age))
print(type(height))
print(type(igbo_nativity))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
#Exercise 5_Dynamic Typing
X = ("Promise Steve")
X = 2003
print(type(X))
# Out:
# <class 'int'>

# %%
## STUDENT INFORMATION CARD
Name = input("Name: ")
Age = int(input("Age: "))
Course = input("Course: ")
Country = input("Country: ")
print(Name)
print(Age)
print(Course)
print(Country)

print(type(Name))
print(type(Age))
print(type(Course))
print(type(Country))
# Out:
# Name:  Promise Steve
# Age:  26
# Course:  Python Programming
# Country:  Nigeria
# Promise Steve
# 26
# Python Programming
# Nigeria
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
