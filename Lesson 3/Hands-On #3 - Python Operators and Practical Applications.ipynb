# %%
#Questioon 1_Employee Payroll & Bonus Eligibility
basic_salary = 180000
performance_bonus = 45000
total_salary = basic_salary + performance_bonus
print(total_salary)
# Out:
# 225000

# %%
#this line of code confirms employee eligibility for performance bonus
basic_salary = 180000
performance_bonus = 45000
basic_salary >= performance_bonus
# Out:
# True

# %%
#Question 2_student_performance_Evaluation
Python = 72
SQL =65
Excel = 80
Power_Bi = 75
total_score = Python + SQL + Excel + Power_Bi
print(total_score)
# Out:
# 292

# %%
Python = 72
SQL =65
Excel = 80
Power_Bi = 75
average_score = (Python + SQL + Excel + Power_Bi) / 4
print(average_score)
# Out:
# 73.0

# %%
average_score = 73.0
Passed = 70
average_score >= Passed
# Out:
# True

# %%
#Question 3_Inventory Management System
initial_stock = 250
solid = 85
remaining_stock = initial_stock - solid
print(remaining_stock)
# Out:
# 165

# %%
Remaining_stock = 165
Reorder_needed <= 200
# Out:
# True

# %%
#Question 4_Banking_Withdrawal_Checker
Account_balance = 520000
Customer_wants_to_withdraw = 150000
Remaining_balance = Account_balance - Customer_wants_to_withdraw
print(Remaining_balance)
# Out:
# 370000

# %%
Remaining_balance = 370000
withdrawal_approved = 150000
Remaining_balance >= withdrawal_approved
# Out:
# True

# %%
#Bonus Challenge_smart shopping discount challenge
laptop_bag = 18500
wireless_mouse = 12000
keyboard = 24500
USB_drive = 5000
total_purchase_amount = laptop_bag + wireless_mouse + keyboard + USB_drive
print(total_purchase_amount)
# Out:
# 60000

# %%
# Check if customer qualifies for discount
total_purchase_amount = 60000
total_purchase_amount >= 50000
# Out:
# True

# %%
#calculating discount amount
total_purchase_amount = 60000
discount = total_purchase_amount * 0.10
print(discount)
# Out:
# 6000.0

# %%
#calculating final amount to pay
total_purchasae_amount = 60000
discount = 6000
