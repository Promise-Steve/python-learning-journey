# %%
#This section demonstrates the use of the print () function

# %%
print ("Hello world")
# Out:
# Hello world

# %%
print ("My name is Chukwuemeka Somtochukwu Promise")
# Out:
# My name is Chukwuemeka Somtochukwu Promise

# %%
print ("I am learning python")
# Out:
# I am learning python

# %%
print ("Programming is exciting")
# Out:
# Programming is exciting

# %%
#This section demonstrates multiple print () function

# %%
print ("My favourite food is fufu and Afang Soup with assorted proteins")
# Out:
# My favourite food is fufu and Afang Soup with assorted proteins

# %%
print ("My favourite movie is 'THE WHEEL OF TIME SERIES'")
# Out:
# My favourite movie is 'THE WHEEL OF TIME SERIES'

# %%
print ("My favourite sport is  Football/Soccer")
# Out:
# My favourite sport is  Football/Soccer

# %%
print ("My favourite colour is coffee brown")
# Out:
# My favourite colour is coffee brown

# %%
#This section demonstrates the python calculator

# %%
print (15 + 5)
# Out:
# 20

# %%
print (30 - 12)
# Out:
# 18

# %%
print (9 * 8)
# Out:
# 72

# %%
print (72 / 9)
# Out:
# 8.0

# %%
print (18 % 5)
# Out:
# 3

# %%
print (10 // 3)
# Out:
# 3

# %%
print (5 ** 2)
# Out:
# 25

# %%
#This section demonstrates understanding comments

# %%
#Display programming language

# %%
print ("Python")
# Out:
# Python

# %%
#diplay list of steps to instruct computer

# %%
print ("Programmming")
# Out:
# Programmming

# %%
#Displays lesson eye

# %%
print ("Lesson one")
# Out:
# Lesson one

# %% [markdown]
# #Exercise 5

# %%
print ("My name is Chukwuemeka Somtochukwu Promise")
# Out:
# My name is Chukwuemeka Somtochukwu Promise

# %%
print (" My dream course was Law")
# Out:
#  My dream course was Law

# %%
#displays my country
print ("My native Coutry is Nigeria")
# Out:
# My native Coutry is Nigeria

# %%
print (25 + 75)
# Out:
# 100

# %%
# divides the number and returns only the whoe number
print (40 // 6)
# Out:
# 6

# %%
#calculates 8 raised to the power of 2
print (8 ** 2)
# Out:
# 64
