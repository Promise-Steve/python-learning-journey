# %% [raw]
# #### --- Decision Making in Python (if, elif, else, Logical Operators & Comparison Chaining)

# %% [markdown]
# ## --- Hands-on Exercise 1: Pharmacy Prescription Checker

# %%
# --- Creating variables
customer_age = 25

# --- display logical response
print("Adult Prescription Approved" if customer_age >= 18 else "Parental Approval Required")
# Out:
# Adult Prescription Approved

# %% [markdown]
# ## --- Hands-on Exercise 2: Employee Performance Rating

# %%
# --- creating variables
performance_score = 98

if performance_score <= 60:
    print("Needs improvement") 
elif performance_score <= 74:
    print("Meets Expectation")                                                    
elif performance_score <= 89:
    print("Exceeds Expectation")
                                                        
else:
    print("Outstanding")
# Out:
# Outstanding

# %% [markdown]
# ## --- Hands-on Exercise 3: Secure Company Login System

# %%
# --- creating variables

is_employee = True
account_active = True
account_locked = False

# --- displaying logical statement to either grant or deny access
print("Access Granted" if is_employee and account_active and not account_locked else "Access Denied")
# Out:
# Access Granted

# %% [markdown]
# ## --- SmartBiz Student Scholarship Eligibility System

# %%
# --- Declaring variables

student_name = "Okpara Naomi C."
age = 23
exam_score = 85
interview_passed = True
has_disciplinary_case = False

# --- evaluating candidate's scholarship eligibility
if (age >= 16
    and exam_score >= 80
    and interview_passed == True
    and has_disciplinary_case == False
):
    print("Congratulations! You have been awarded the SmartBiz Scholarship.")
else: 
    print("Sorry, you do not meet the scholarship requirements.")

# --- evaluating candidate standing based on exam_score
if exam_score <= 80:
    print("Did not Meet Academic Requirement")
elif exam_score <= 89:
    print("Strong Candidate")
else:
    print("Excellent Candidate")
# Out:
# Congratulations! You have been awarded the SmartBiz Scholarship.
# Strong Candidate
