# %%
# --- Ex 1. Creating a customer profile registration at StartX Digital Solutions
# --- Variable creation

customer_details = """Name: Isreal Jacobs
Email: isrealjacobs265@gmail.com
Phone: +447608342943
Country: England
Occupation: Data Scientist/Business Analyst"""

print(customer_details)
# Out:
# Name: Isreal Jacobs
# Email: isrealjacobs265@gmail.com
# Phone: +447608342943
# Country: England
# Occupation: Data Scientist/Business Analyst

# %%
# --- Ex 2. Hospital Patient Record

patient_record = """Patient: Steve Harper
Doctor: Charles Wayne
Diagnosis: Hyperglycemia
Blood Group: AB
Hospital: Newtons Specialist Hospital, Ontario, Canada"""

print(patient_record)
# Out:
# Patient: Steve Harper
# Doctor: Charles Wayne
# Diagnosis: Hyperglycemia
# Blood Group: AB
# Hospital: Newtons Specialist Hospital, Ontario, Canada

# %%
# --- Ex 3. A.I Prompt Builder

prompt = """You are an AI Assistant.
Analyze customer feedback.
Identify common complaints.
Provide recommendations.
Generate a summary report.
Then build a professional dashboard summary
Give a brief analysis report to understand the dashboard"""

print(prompt)
# Out:
# You are an AI Assistant.
# Analyze customer feedback.
# Identify common complaints.
# Provide recommendations.
# Generate a summary report.
# Then build a professional dashboard summary
# Give a brief analysis report to understand the dashboard

# %%
# --- CASE STUDY PROJECT (Customer Feedback Management System)
welcome_address = '''=================================================
WELCOME TO INSIGHT RETAIL TECHNOLOGIES
A HOME OF MODERN TECH. 
ENJOY THE AESTHETICS
LOVE THE AMBIENCE
=================================================='''

customer_report = """==================================================
CUSTOMER FEEDBACK REPORT
==================================================
Customer Name: Sarah Johnson
Product: Wireless Mouse
Category: Computer Accessories
Rating: 5 stars

Customer Review
-----------------------------------------
The product arrived on time, was easy to install, 
and exceeded my expectations.
I would definitely recommend it to others.

====================================================
Thank you for your feedback!
====================================================
Insight Retail Technologies, insight@retailtech.com"""

print(welcome_address)
print(customer_report)
# Out:
# ...
# WELCOME TO INSIGHT RETAIL TECHNOLOGIES
# A HOME OF MODERN TECH.
# ENJOY THE AESTHETICS
# LOVE THE AMBIENCE
# ...
# CUSTOMER FEEDBACK REPORT
# ...
# Customer Name: Sarah Johnson
# Product: Wireless Mouse
# Category: Computer Accessories
# Rating: 5 stars
#
# Customer Review
# -----------------------------------------
# The product arrived on time, was easy to install,
# and exceeded my expectations.
# I would definitely recommend it to others.
#
# ...
# Thank you for your feedback!
# ...
# Insight Retail Technologies, insight@retailtech.com
